# %%
import pandas as pd
import bioinfokit
from bioinfokit import analys, visuz

# %%
data3_path = "/Users/Client/My Drive/PhD/Programing/R/Datasets/Cerebrospinal/ALS-C.csv"
dat3=pd.read_csv(data3_path, header=0)

# %%
dat3.head()
# Out:
#   Gene names   Mean ALS  Mean Control  Log2 ALS-C   TTEST ALS-C  Rank  \
# 0      CHIT1  15.898910     13.762277    0.208209  4.370000e-10     1
# 1        C8A  16.278776     15.784189    0.044512  2.689220e-04     2
# 2       NBEA  14.788685     14.347207    0.043724  5.732530e-04     3
# 3     CHI3L1  18.816268     18.249903    0.044092  6.922860e-04     4
# 4     LINGO1  12.279528     13.633833   -0.150936  7.873920e-04     5
#
#       P adj
# 0  1.000000
# 1  0.106627
# 2  0.151530
# 3  0.137246
# 4  0.124880

# %%
bioinfokit.visuz.GeneExpression.volcano(df=dat3, lfc="Log2 ALS-C", pv="TTEST ALS-C",
                                        ar=0, show=True, plotlegend=True, legendpos = "center right",
                                        lfc_thr=(0.2, 0.2), pv_thr=(0.01, 0.05), sign_line=True, genenames="deg", geneid='Gene names')
#needed to reduce the treshold as didn`t want to create the plot

# %%
data4_path = "/Users/Client/My Drive/PhD/Programing/R/Datasets/CSF extracellular/CSF extracellular.csv"
dat4=pd.read_csv(data4_path, header=0)
dat4.head()
# Out:
#   Primary Uniprot Accession     Mean +     Mean -      Log2     Ttest  Rank  \
# 0                       PLG  13.301316  10.300117  0.368908  0.014769     1
# 1                   SLITRK4  11.153125  14.203090 -0.348757  0.035805     2
# 2                    TUBA1A  16.823156  18.058579 -0.102236  0.053801     3
# 3                     VLDLR  11.642991  10.532402  0.144627  0.060423     4
# 4                       LPA  10.176909  11.698678 -0.201046  0.061939     5
#
#        P Adj
# 0  15.064569
# 1  18.260539
# 2  18.292264
# 3  15.407774
# 4  12.635636

# %%
bioinfokit.visuz.GeneExpression.volcano(df=dat4, lfc="Log2", pv="Ttest",
                                        ar=0, show=True, plotlegend=True, legendpos = "center right",
                                        lfc_thr=(0.1, 0.2), pv_thr=(0.05, 0.05), sign_line=True, genenames="deg", geneid='Primary Uniprot Accession')
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-146-cd92de4c87e0> in <module>
# ----> 1 bioinfokit.visuz.GeneExpression.volcano(df=dat4, lfc="Log2", pv="Ttest",
#       2                                         ar=0, show=True, plotlegend=True, legendpos = "center right",
#       3                                         lfc_thr=(0.1, 0.2), pv_thr=(0.05, 0.05), sign_line=True, genenames="deg", geneid='Primary Uniprot Accession')
#
# c:\users\client\appdata\local\programs\python\python38-32\lib\site-packages\bioinfokit\visuz.py in volcano(df, lfc, pv, lfc_thr, pv_thr, color, valpha, geneid, genenames, gfont, dim, r, ar, dotsize, markerdot, sign_line, gstyle, show, figtype, axtickfontsize, axtickfontname, axlabelfontsize, axlabelfontname, axxlabel, axylabel, xlm, ylm, plotlegend, legendpos, figname, legendanchor, legendlabels, theme)
# ...

# %%
data5_path = "/Users/Client/My Drive/PhD/Programing/R/Datasets/Machine learning/ML Stat Plasma.csv"
dat5=pd.read_csv(data5_path, header=0)
dat5.head()
# Out:
#       Genes   Mean ALS  Mean Healthy      Log2     Ttest  Rank      P adj
# 0      PRG4  27.309554     26.481372  0.044428  0.000533      1  0.113071
# 1  SERPINA6  31.202708     31.533215 -0.015201  0.004638      2  0.491578
# 2       CFH  34.031670     33.820465  0.008981  0.005055      3  0.357196
# 3  SERPINC1  33.820613     34.005435 -0.007863  0.005246      4  0.278015
# 4        CP  35.518498     35.760031 -0.009777  0.006389      5  0.270890

# %%
bioinfokit.visuz.GeneExpression.volcano(df=dat5, lfc="Log2", pv="Ttest",
                                        ar=0, show=True, plotlegend=True, legendpos = "center right",
                                        lfc_thr=(0.02, 0.02), pv_thr=(0.01, 0.05), sign_line=True, 
                                        genenames="deg", geneid='Genes')

# %%
data6_path = "/Users/Client/My Drive/PhD/Programing/R/Datasets/Machine learning/ML Stat CSF.csv"
dat6=pd.read_csv(data6_path, header=0)
dat6.head()
# Out:
#       Genes     Mean ALS  Mean Healthy      Log2         Ttest  Rank   \
# 0    CHI3L1  30.12692125     29.328000  0.038775  4.490000e-07      1
# 1  SERPINA3  32.94774656     32.182365  0.033909  8.680000e-06      2
# 2      APOD  33.21722688     32.762663  0.019879  2.165510e-04      3
# 3    CHI3L2  24.12527656     23.191698  0.056937  1.875460e-04      4
# 4       APP      30.8417     31.321962 -0.022292  2.880430e-04      5
#
#       P adj
# 0  0.000161
# 1  0.001554
# 2  0.025842
# 3  0.016785
# 4  0.020624

# %%
bioinfokit.visuz.GeneExpression.volcano(df=dat6, lfc="Log2", pv="Ttest",
                                        ar=0, show=True, plotlegend=True, legendpos = "center right",
                                        lfc_thr=(0.01, 0.02), pv_thr=(0.01, 0.05), sign_line=True, 
                                        genenames="deg", geneid='Genes')

# %%
data7_path = "/Users/Client/My Drive/PhD/Programing/R/Datasets/Proteomic of exosome/exosome stat.csv"
dat7=pd.read_csv(data7_path, header=0)
dat7.head()
# Out:
#   Gene name     Log 2     Ttest  Rank      P adj
# 0    PTPRZ1 -1.321496  0.003848      1  1.285372
# 1     NOC2L  1.259413  0.008908      2  1.487644
# 2    CCDC19 -1.597181  0.013804      3  1.536890
# 3     MARCO -0.766663  0.017846      4  1.490178
# 4      RELN -1.294514  0.021608      5  1.443391

# %%
bioinfokit.visuz.GeneExpression.volcano(df=dat7, lfc="Log 2", pv="Ttest",
                                        ar=0, show=True, plotlegend=True, legendpos = "center right",
                                        lfc_thr=(0.02, 0.04), pv_thr=(0.01, 0.05), sign_line=True, 
                                        genenames="deg", geneid='Gene name')
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-107-b0835028d9ad> in <module>
# ----> 1 bioinfokit.visuz.GeneExpression.volcano(df=dat7, lfc="Log 2", pv="Ttest",
#       2                                         ar=0, show=True, plotlegend=True, legendpos = "center right",
#       3                                         lfc_thr=(0.02, 0.04), pv_thr=(0.01, 0.05), sign_line=True,
#       4                                         genenames="deg", geneid='Gene name')
#
# ...

# %%
bioinfokit.visuz.GeneExpression.volcano(df=dat9, lfc='Log 2', pv='Ttest',
                                        ar=0, show=True, plotlegend=True, legendpos = "center right",
                                        lfc_thr=(0.02, 0.04), pv_thr=(0.01, 0.05), sign_line=True, 
                                        genenames="deg", geneid='Gene.names')

# %%
data_path = "/Users/Client/My Drive/PhD/Programing/R/Datasets/A Proteomic Network/A prot ALS stats.csv"
datp=pd.read_csv(data_path, header=0)
datp
# Out:
#      Gene names    SD ALL  Mean Control  Mean ALS  SD Control    SD ALS  \
# 0           HN1  0.118467     -0.297499 -0.411912    0.062816  0.104092
# 1      SELENBP1  0.132423      0.363716  0.452963    0.046117  0.087713
# 2         GNAI1  0.063795      1.003355  0.945796    0.039300  0.044876
# 3          KLC1  0.044351      0.549438  0.503507    0.032880  0.036126
# 4         SRPRB  0.139792     -0.629207 -0.774283    0.084378  0.149598
# ...         ...       ...           ...       ...         ...       ...
# 2576     PICALM  0.070085     -0.230068 -0.230024    0.054745  0.057806
# 2577    CEP170B  0.190107     -0.469906 -0.469985    0.117698  0.149072
# 2578      ATP5J  0.068718      1.045695  1.045725    0.070590  0.062001
# 2579       GPS1  0.039256      0.138911  0.138926    0.041847  0.033112
# 2580     COL6A1  0.709844      0.012772  0.012787    0.773786  0.863587
#
#       FC ALS-C  Log2FC ALS-C  SE Control    SE ALS  SED ALS-Control  \
# ...

# %%
bioinfokit.visuz.GeneExpression.volcano(df=datp, lfc='Log2FC ALS-C', pv='P Value ALS',
                                        ar=0, show=True, plotlegend=True, legendpos = "center right",
                                        lfc_thr=(0.1, 0.1), pv_thr=(0.05, 0.05), sign_line=True, 
                                        genenames="deg", geneid='Gene names')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-12-16abfe573bea> in <module>
# ----> 1 bioinfokit.visuz.GeneExpression.volcano(df=datp, lfc='Log2FC ALS-C', pv='P Value ALS',
#       2                                         ar=0, show=True, plotlegend=True, legendpos = "center right",
#       3                                         lfc_thr=(0.1, 0.1), pv_thr=(0.05, 0.05), sign_line=True,
#       4                                         genenames="deg", geneid='Gene names')
#
# NameError: name 'datp' is not defined

# %%
pro=pd.read_excel(r"C:\Users\Client\My Drive\PhD\Programing\R\Datasets\A Proteomic Network\A prot scale stats.xlsx", header=0, index_col=False)

# %%
pro
# Out:
#      Gene names  Control 1  Control 2  Control 3  Control 4  Control 5  \
# 0         IGHG2   2.454342   2.484880   2.282489   2.159420   2.594948
# 1        SLC4A1   2.375419   2.546338   1.936016   2.411678   2.770939
# 2          HBA2   4.738164   4.726352   4.738635   4.823087   4.897498
# 3          ORM1   1.768504   2.228121   1.977445   1.903978   2.061440
# 4           FGG   2.711708   3.446885   2.339259   3.030791   2.819987
# ...         ...        ...        ...        ...        ...        ...
# 2607     ATP2B4   2.334528   2.295649   2.168032   1.973522   1.996935
# 2608     COL6A1   1.548522   3.237192   1.834923   2.114882   2.942412
# 2609      IDH3A   3.528360   3.478265   3.502843   3.365420   3.540890
# 2610       MFN2   2.300674   2.299663   2.101985   2.172119   2.308623
# 2611       CST3   2.351679   2.274555   2.429874   2.492460   2.548041
#
#       Control 6  Control 7  Control 8     ALS 1  ...  SED FTD-Control  \
# ...

# %%
pro_ivo=pro.iloc[:,:77]
pro_ivo
# Out:
#      Gene names  Control 1  Control 2  Control 3  Control 4  Control 5  \
# 0         IGHG2   2.454342   2.484880   2.282489   2.159420   2.594948
# 1        SLC4A1   2.375419   2.546338   1.936016   2.411678   2.770939
# 2          HBA2   4.738164   4.726352   4.738635   4.823087   4.897498
# 3          ORM1   1.768504   2.228121   1.977445   1.903978   2.061440
# 4           FGG   2.711708   3.446885   2.339259   3.030791   2.819987
# ...         ...        ...        ...        ...        ...        ...
# 2607     ATP2B4   2.334528   2.295649   2.168032   1.973522   1.996935
# 2608     COL6A1   1.548522   3.237192   1.834923   2.114882   2.942412
# 2609      IDH3A   3.528360   3.478265   3.502843   3.365420   3.540890
# 2610       MFN2   2.300674   2.299663   2.101985   2.172119   2.308623
# 2611       CST3   2.351679   2.274555   2.429874   2.492460   2.548041
#
#       Control 6  Control 7  Control 8     ALS 1  ...  SED ALS-FTD-Control  \
# ...

# %%
visuz.GeneExpression.volcano(df=pro_ivo, lfc='Log2FC ALS-C', pv='P Value ALS', lfc_thr=(0.01, 0.01), pv_thr=(0.05, 0.05), show=True,genenames="deg", geneid='Gene names')
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-56-f0165387b2aa> in <module>
# ----> 1 visuz.GeneExpression.volcano(df=pro_ivo, lfc='Log2FC ALS-C', pv='P Value ALS', lfc_thr=(0.01, 0.01), pv_thr=(0.05, 0.05), show=True,genenames="deg", geneid='Gene names')
#
# c:\users\client\appdata\local\programs\python\python38-32\lib\site-packages\bioinfokit\visuz.py in volcano(df, lfc, pv, lfc_thr, pv_thr, color, valpha, geneid, genenames, gfont, dim, r, ar, dotsize, markerdot, sign_line, gstyle, show, figtype, axtickfontsize, axtickfontname, axlabelfontsize, axlabelfontname, axxlabel, axylabel, xlm, ylm, plotlegend, legendpos, figname, legendanchor, legendlabels, theme)
#     174             plt.axvline(x=lfc_thr[0], linestyle='--', color='#7d7d7d', linewidth=1)
#     175             plt.axvline(x=-lfc_thr[1], linestyle='--', color='#7d7d7d', linewidth=1)
# ...

# %%
pro2= pro
pro2.style.hide_index()
pro2
# Out:
#      Gene names  Control 1  Control 2  Control 3  Control 4  Control 5  \
# 0         IGHG2   2.454342   2.484880   2.282489   2.159420   2.594948
# 1        SLC4A1   2.375419   2.546338   1.936016   2.411678   2.770939
# 2          HBA2   4.738164   4.726352   4.738635   4.823087   4.897498
# 3          ORM1   1.768504   2.228121   1.977445   1.903978   2.061440
# 4           FGG   2.711708   3.446885   2.339259   3.030791   2.819987
# ...         ...        ...        ...        ...        ...        ...
# 2607     ATP2B4   2.334528   2.295649   2.168032   1.973522   1.996935
# 2608     COL6A1   1.548522   3.237192   1.834923   2.114882   2.942412
# 2609      IDH3A   3.528360   3.478265   3.502843   3.365420   3.540890
# 2610       MFN2   2.300674   2.299663   2.101985   2.172119   2.308623
# 2611       CST3   2.351679   2.274555   2.429874   2.492460   2.548041
#
#       Control 6  Control 7  Control 8     ALS 1  ...  SED FTD-Control  \
# ...

# %%
bioinfokit.visuz.GeneExpression.volcano(df=pro, lfc='Log2FC ALS-C', pv='P Value ALS',
                                        ar=0, show=True, plotlegend=True, legendpos = "center right",
                                        lfc_thr=(0.01, 0.01), pv_thr=(0.05, 0.05), sign_line=True, 
                                        genenames="deg", geneid='Gene names')

# %%
cer = pd.read_excel(r"C:\Users\Client\My Drive\PhD\Programing\R\Datasets\Cerebrospinal\Cereb stats No NA.xlsx",
                     header=0, index_col=False)

# %%
bioinfokit.visuz.GeneExpression.volcano(df=cer, lfc='Log2FC ALS-C', pv='P Value ALS',
                                        ar=0, show=True, plotlegend=True, legendpos = "center right",
                                        lfc_thr=(0.01, 0.01), pv_thr=(0.05, 0.05), sign_line=True, 
                                        genenames="deg", geneid='Gene names')
# Out:
# c:\users\client\appdata\local\programs\python\python38-32\lib\site-packages\pandas\core\arraylike.py:364: RuntimeWarning: divide by zero encountered in log10
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# <__array_function__ internals>:180: UserWarning: Warning: converting a masked element to nan.
# c:\users\client\appdata\local\programs\python\python38-32\lib\site-packages\matplotlib\colors.py:1211: UserWarning: Warning: converting a masked element to nan.
#   data = np.asarray(value)
# c:\users\client\appdata\local\programs\python\python38-32\lib\site-packages\matplotlib\ticker.py:547: UserWarning: Warning: converting a masked element to nan.
#   if self._useLocale else fmt % arg)
# posx and posy should be finite values
# posx and posy should be finite values

# %%
ext = pd.read_excel(r"C:\Users\Client\My Drive\PhD\Programing\R\Datasets\CSF extracellular\CSF extracellular scale down stats.xlsx",
                     header=0, index_col=False)

# %%
bioinfokit.visuz.GeneExpression.volcano(df=ext, lfc='Log2FC ALS-C', pv='P Value ALS',
                                        ar=0, show=True, plotlegend=True, legendpos = "center right",
                                        lfc_thr=(0.01, 0.01), pv_thr=(0.05, 0.05), sign_line=True, 
                                        genenames="deg", geneid='Gene names')

# %%
rev = pd.read_excel(r"C:\Users\Client\My Drive\PhD\Programing\R\Datasets\Revealing the proteome\Revealing stats.xlsx",
                     header=0, index_col=False)
rev
# Out:
#               Gene names     ALS 1     ALS 2     ALS 3     ALS 4     ALS 5  \
# 0                 RPS27A  0.851960  1.007752  0.833170  1.468071  1.131373
# 1                   CYCS  1.154521  1.298949  1.137101  1.725692  1.413553
# 2                  HLA-A  1.335692  1.373728  1.529889  1.432448  1.012165
# 3                 CYP1B1  0.143600  0.000000  0.719744  0.427844  0.000000
# 4                  CD177  0.075792  0.260735  0.053486  0.000000  0.407487
# ...                  ...       ...       ...       ...       ...       ...
# 1530                RTN4  2.799769  2.912177  2.948406  3.145805  3.011511
# 1531                KRT2  2.485029  3.086190  3.474185  2.749923  3.054838
# 1532               PRDX2  2.810206  3.069088  2.955360  3.151782  2.844490
# 1533               GRHPR  1.547591  1.677257  1.531953  2.060380  1.780146
# 1534  DKFZp566H1924;NPTN  3.007832  3.097052  2.784207  3.371605  3.084536
#
# ...

# %%
bioinfokit.visuz.GeneExpression.volcano(df=rev, lfc='Log2FC ALS-NC', pv='P Value ALS',
                                        ar=0, show=True, plotlegend=True, legendpos = "center right",
                                        lfc_thr=(0.01, 0.01), pv_thr=(0.05, 0.05), sign_line=True, 
                                        genenames="deg", geneid='Gene names')

# %%
ast=pd.read_excel (r"C:\Users\Client\OneDrive - Queen Mary, University of London\PhD\PhD back up\Programing full\R\Datasets\Cell Lines\Reactive astro\Reactive astrocytes for volcano.xlsx",
                  header=0, index_col=False )
ast
# Out:
#      Gene names  Log2 FC     TTEST
# 0          AAK1   -0.252  0.694024
# 1         AAMDC    0.537  0.547581
# 2        AARSD1    0.862  0.137399
# 3         ABCF1    0.722  0.101150
# 4          ABI1   -1.700  0.025671
# ...         ...      ...       ...
# 1156       VARS   -1.140  0.076959
# 1157       WARS   -1.110  0.098973
# 1158       WIBG   -0.272  0.605367
# 1159       YARS    0.733  0.304737
# 1160       YARS    0.733  0.304737
#
# [1161 rows x 3 columns]

# %%
bioinfokit.visuz.GeneExpression.volcano(df=ast, lfc='Log2 FC', pv='TTEST',
                                        ar=0, show=True, plotlegend=True, legendpos = "center right",
                                        lfc_thr=(1, 1), pv_thr=(0.01, 0.01), sign_line=True, 
                                        genenames="deg", geneid='Gene names')
