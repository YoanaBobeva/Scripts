# %%
import pandas as pd
from pandas import DataFrame
import numpy as np
import bioinfokit as bik
from bioinfokit import analys, visuz
from scipy import stats 
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import MinMaxScaler

# %%
data_path = "/Users/Client/My Drive/PhD/Programing/R/Datasets/A Proteomic Network/A Prot net.csv"
dats=pd.read_csv(data_path, header=0, index_col=0)
#dat=pd.read_csv(data_path, header=0)
dats
# Out:
#             Control 1  Control 2  Control 3  Control 4  Control 5  Control 6  \
# Gene names
# TUBA1A      35.340465  35.360227  35.316990  35.629164  35.306858  35.208816
# HBB         34.805838  34.799389  34.960708  35.679915  35.640050  34.863775
# TUBB4B      35.237408  35.229361  35.225127  35.423859  35.175022  35.164483
# ACTG1       35.080176  35.035111  35.046158  35.221391  34.970036  35.054252
# HBA2        34.441864  34.415416  34.430065  35.063952  35.273882  34.427993
# ...               ...        ...        ...        ...        ...        ...
# MEAF6       18.180863  18.275198  18.508010  18.271233  18.565836  18.541315
# ACBD5       18.497584  18.438914  18.571335  19.681870  18.498736  18.582755
# SLC4A8      19.214524  18.096978  18.349789  18.591834  18.707311  18.852882
# PPIG        18.211645  18.170713  18.864304  19.514376  18.430147  18.518114
# DYRK1A      19.098626  18.865406  18.761203  18.573327  18.981618  19.284701
#
# ...

# %%
#Normalizing in 0-5 range 
trans = MinMaxScaler(feature_range=(0,5))
scal = trans.fit_transform(dats)

# %%
scal
# Out:
# array([[5.        , 5.        , 5.        , ..., 4.94838367, 5.        ,
#         5.        ],
#        [4.84421928, 4.83756281, 4.89500856, ..., 5.        , 4.9635907 ,
#         4.88972284],
#        [4.96997096, 4.96209679, 4.97292929, ..., 4.90316885, 4.97266033,
#         4.96508605],
#        ...,
#        [0.30119012, 0.        , 0.        , ..., 0.4030784 , 0.48462173,
#         0.37896147],
#        [0.00896921, 0.02135611, 0.15162061, ..., 0.        , 0.03852179,
#         0.11903324],
#        [0.26741959, 0.22256189, 0.12123801, ..., 0.19021342, 0.1845191 ,
#         0.09561538]])

# %%
# convert the array back to a dataframe
down = pd.DataFrame(scal)
down
# Out:
#             0         1         2         3         4         5         6   \
# 0     5.000000  5.000000  5.000000  4.985424  4.906729  5.000000  5.000000
# 1     4.844219  4.837563  4.895009  5.000000  5.000000  4.907834  4.653057
# 2     4.969971  4.962097  4.972929  4.926457  4.869824  4.988158  4.989737
# 3     4.924156  4.905836  4.920189  4.868306  4.812442  4.958713  4.936005
# 4     4.738164  4.726352  4.738635  4.823087  4.897498  4.791429  4.599243
# ...        ...       ...       ...       ...       ...       ...       ...
# 2604  0.000000  0.051619  0.046626  0.000000  0.220396  0.547835  0.015820
# 2605  0.092287  0.099036  0.065287  0.405153  0.201613  0.558904  0.203790
# 2606  0.301190  0.000000  0.000000  0.092081  0.259999  0.631060  0.560209
# 2607  0.008969  0.021356  0.151621  0.357047  0.182412  0.541638  0.146120
# 2608  0.267420  0.222562  0.121238  0.086765  0.336786  0.746406  0.148474
#
# ...

# %%
col=list(dats.columns)
col
# Out:
# ['Control 1',
#  'Control 2',
#  'Control 3',
#  'Control 4',
#  'Control 5',
#  'Control 6',
#  'Control 7',
#  'Control 8',
#  'ALS 1',
#  'ALS 2',
#  'ALS 3',
#  'ALS 4',
#  'ALS 5',
#  'ALS 6',
#  'ALS 7',
#  'ALS 8',
#  'ALS 9',
#  'ALS 10',
#  'ALS 11',
#  'ALS 12',
#  'ALS 13',
#  'ALS 14',
#  'ALS 15',
#  'ALS 16',
#  'ALS 17',
#  'ALS 18',
#  'ALS 19',
#  'ALS-FTD 1',
#  'ALS-FTD 2',
#  'ALS-FTD 3',
#  'ALS-FTD 4',
#  'ALS-FTD 5',
#  'ALS-FTD 6',
#  'ALS-FTD 7',
#  'ALS-FTD 8',
#  'ALS-FTD 9',
#  'ALS-FTD 10',
#  'FTD 1',
#  'FTD 2',
#  'FTD 3',
#  'FTD 4',
#  'FTD 5',
#  'FTD 6',
#  'FTD 7',
#  'FTD 8',
#  'FTD 9',
#  'FTD 10']

# %%
ro=list(dats.index)
ro
# Out:
# ['TUBA1A',
#  'HBB',
#  'TUBB4B',
#  'ACTG1',
#  'HBA2',
#  'GFAP',
#  'DPYSL2',
#  'MBP',
#  'GAPDH',
#  'SPTAN1',
#  'CKB',
#  'SPTBN1',
#  'CLTC',
#  'CNP',
#  'PKM',
#  'STXBP1',
#  'NEFM',
#  'ALDOA',
#  'ATP5B',
#  'ALB',
#  'ATP1A2',
#  'PLP1',
#  'SYN1',
#  'BASP1',
#  'YWHAZ',
#  'ATP5A1',
#  'TUBB2A',
#  'HSPA8',
#  'NEFL',
#  'PEBP1',
#  'UCHL1',
#  'PGK1',
#  'MDH2',
#  'GNAO1',
#  'CALM1',
#  'HSP90AA1',
#  'TUBB4A',
#  'GNB1',
#  'DYNC1H1',
#  'PLEC',
#  'ENO1',
#  'LDHB',
#  'MAP1B',
#  'DNM1',
#  'ACO2',
#  'MAP2',
#  'YWHAG',
#  'HK1',
#  'GDI1',
#  'ATP1A1',
#  'ALDOC',
#  'YWHAE',
#  'ATP1A3',
#  'VIM',
#  'GAP43',
#  'ANK2',
#  'NSF',
#  'PPIA',
#  'INA',
#  'GPI',
#  'TUBB3',
#  'CAMK2B',
#  'PRDX2',
#  'ACTC1',
#  'MDH1',
#  'CAMK2A',
#  'GLUD1',
#  'CFL1',
#  'SLC1A2',
#  'HSPD1',
#  'DDAH1',
#  'TUBA1B',
#  'HIST1H2BM',
#  'PRDX1',
#  'ENO2',
#  'GOT1',
#  'MAP1A',
#  'VCAN',
#  'NCAM1',
#  'CKMT1A',
#  'ATP6V1A',
#  'AP2B1',
#  'HSPA1B',
#  'STX1B',
# ...

# %%
down = pd.DataFrame(scal, columns= col, index=ro)
down
# Out:
#         Control 1  Control 2  Control 3  Control 4  Control 5  Control 6  \
# TUBA1A   5.000000   5.000000   5.000000   4.985424   4.906729   5.000000
# HBB      4.844219   4.837563   4.895009   5.000000   5.000000   4.907834
# TUBB4B   4.969971   4.962097   4.972929   4.926457   4.869824   4.988158
# ACTG1    4.924156   4.905836   4.920189   4.868306   4.812442   4.958713
# HBA2     4.738164   4.726352   4.738635   4.823087   4.897498   4.791429
# ...           ...        ...        ...        ...        ...        ...
# MEAF6    0.000000   0.051619   0.046626   0.000000   0.220396   0.547835
# ACBD5    0.092287   0.099036   0.065287   0.405153   0.201613   0.558904
# SLC4A8   0.301190   0.000000   0.000000   0.092081   0.259999   0.631060
# PPIG     0.008969   0.021356   0.151621   0.357047   0.182412   0.541638
# DYRK1A   0.267420   0.222562   0.121238   0.086765   0.336786   0.746406
#
#         Control 7  Control 8     ALS 1     ALS 2  ...     FTD 1     FTD 2  \
# ...

# %%
down.to_excel(r"C:\Users\Client\My Drive\PhD\Programing\R\Datasets\A Proteomic Network\A prot net scaled down.xlsx")

# %%
tran=pd.read_excel(r"C:\Users\Client\OneDrive - Queen Mary, University of London\PhD\PhD back up\Programing full\R\Datasets\Transpose.xlsx", header=0)
tran2= tran.T
tran2.head()
# Out:
#               0      1        2       3    4      5     6      7      8    \
# Gene names  CIRBP  SURF6  HNRNPAB  FAM83H  BLM  SOAT1  FPGS  PLPBP  TAF15
#
#              9    ...   365     366     367   368    369    370    371  \
# Gene names  SETX  ...  JPT2  FKBP1A  SHKBP1  FAT1  NDC80  LAMB3  DTX3L
#
#                372    373   374
# Gene names  PARP14  PARP9  FXR2
#
# [1 rows x 375 columns]

# %%
tran2.to_excel (r"C:\Users\Client\OneDrive - Queen Mary, University of London\PhD\PhD back up\Programing full\R\Datasets\Transpose spatio.xlsx")
